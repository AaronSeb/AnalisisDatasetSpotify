# %%
import pandas as pd

# %%
ruta = ('C:/Users/Aaron/Desktop/Data_carga/dataset_spotify.csv')
data = pd.read_csv(ruta)

# %%
data.shape
# Out:
# (114000, 21)

# %%
data
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
#CONTAR VALORES UNICOS EN MI CAMPO DE DATASET
artistas = data['artists'].nunique()
artistas
# Out:
# 31437

# %%
#información de mi dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
#borro una columna y el implace, sobrescribe en el mismo dataset
data.drop(columns=['Unnamed: 0'],inplace=True)
data
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
#Extraigo un fragmento
fragmento = data.iloc[63792:63798]
fragmento
# Out:
#                      track_id               artists  \
# 63792  1qo8cmbRkIsyFNSPKJWdk9  Misfits;Glenn Danzig
# 63793  3DJGXASfi73pBsoP2NuLS4  Yabai T-Shirts Yasan
# 63794  0aFjjn7ha1E4S6DhfV8YjC            Zeki Müren
# 63795  1dIqodhNiWbsTNepZpptZy               10-FEET
# 63796  3AAaNEtwPWwEhRlueS59c9            Yeni Türkü
# 63797  0cKIahHz7lbJ2jz20uS9wf         Erasmo Carlos
#
#                                              album_name          track_name  \
# 63792                               Legacy Of Brutality           Angelfuck
# 63793                             You need the Tank-top  げんきもりもり!モーリーファンタジー
# 63794          Radyo Günlerinden Canlı Kayıtlar, Vol. 3            Manolyam
# 63795                                        Re: 6-feat           Stay Gold
# 63796  Zülfü Livaneli 50. Yıl - Bir Kuşaktan Bir Kuşağa            Gözlerin
# 63797                                        A Pescaria    Festa de Arromba
#
# ...

# %%
#lo paso a un archivo csv
data.to_csv('data_spotify_clean.csv',index=False)

# %%
#transformo mis columnas a otro tipo de datos en este caso str
data['artists'] = data['artists'].astype(str)

#busco en el campo artist, si contiene ";"
artistas_punto_coma= data[data['artists'].apply(lambda x:';' in x)]
artistas_punto_coma
# Out:
#                       track_id                                 artists  \
# 2       1iJBSr7s7jYXzM8EGcbK5b                  Ingrid Michaelson;ZAYN
# 6       6Vc5wAMmXdKIAM7WUoEb7N    A Great Big World;Christina Aguilera
# 8       0IktbUcnAGrvD03AWnz3Q8               Jason Mraz;Colbie Caillat
# 14      4LbWtBkN82ZRhz9jqzgrb3                Chord Overstreet;Deepend
# 16      6xKeQgzfjixSUld14qUezm                    Andrew Foy;Renee Foy
# ...                        ...                                     ...
# 113966  42bdU7oDyRvyRXaKbUrtfu             Bethel Music;Bethany Wohrle
# 113967  1eZYPovTvmxk3QlVD2VpCX              Bethel Music;Brian Johnson
# 113969  7mD7yAQm4GcifSnWqJdZHi               Bethel Music;Molly Skaggs
# 113975  2yAo8cJDVoMjBMS5MgrO8P  Hillsong Worship;Hillsong Young & Free
# 113989  0XEgJiDryoDd2gIJhVXghd       Bryan & Katie Torwalt;Brock Human
#
#                                  album_name                     track_name  \
# ...

# %%
#CONTAR VALORES UNICOS EN MI CAMPO DE DATASET
artistas = data['artists'].nunique()
artistas
# Out:
# 31437
